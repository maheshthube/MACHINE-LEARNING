# %% [markdown]
# # Step 1 :- Import data & Library

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv(r"D:\Mahesh\IMARTICUS\Machine Learning with python\Clustering\H-clustering/Wine.csv")

# %%
data.shape
# Out:
# (178, 13)

# %% [markdown]
# # Step 2 :-  Dendogram

# %%
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(20, 4))
plt.title("Customer Dendograms")
dend = shc.dendrogram(shc.linkage(data, method='ward',metric='euclidean')) #ward = minimum of variance

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=2,affinity='euclidean', linkage='ward') # ward = minimum

# %%
data['Group']=cluster.fit_predict(data)
data.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Group
# 0   3.92     1065      1
# 1   3.40     1050      1
# ...

# %%
import seaborn as sns 
sns.scatterplot(data['Alcohol'],data['Proline'],
                hue='Group',
                data=data,
                palette="turbo")
# Out:
# <AxesSubplot:xlabel='Alcohol', ylabel='Proline'>

# %%
data
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
data.Group.value_counts(ascending=False)
# Out:
# 0    130
# 1     48
# Name: Group, dtype: int64

# %%
np.sum(data.Group.value_counts(ascending=False).values.tolist())
# Out:
# 178

# %% [markdown]
# # Business Submission

# %%
Final_Output = data.loc[:,["Alcohol","Group"]]
Final_Output
# Out:
#      Alcohol  Group
# 0      14.23      1
# 1      13.20      1
# 2      13.16      1
# 3      14.37      1
# 4      13.24      0
# ..       ...    ...
# 173    13.71      0
# 174    13.40      0
# 175    13.27      0
# 176    13.17      0
# 177    14.13      0
#
# [178 rows x 2 columns]
